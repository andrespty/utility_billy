# %%
from data_manipulation import load_one_day, build_all_day_data
import pandas as pd
import numpy as np

# %%
df = load_one_day("output/daily/usage_day_2026-07-13.csv")

# %%
df.tail()
# Out:
#           date      time     mtime  consumption unit  \
# 19  2026-07-13  07:00 PM  19:00:00         2.45  KWH
# 20  2026-07-13  08:00 PM  20:00:00         2.97  KWH
# 21  2026-07-13  09:00 PM  21:00:00         2.00  KWH
# 22  2026-07-13  10:00 PM  22:00:00         2.18  KWH
# 23  2026-07-13  11:00 PM  23:00:00         0.58  KWH
#
#                  source_file  source_mtime
# 19  usage_day_2026-07-13.csv  1.784387e+09
# 20  usage_day_2026-07-13.csv  1.784387e+09
# 21  usage_day_2026-07-13.csv  1.784387e+09
# 22  usage_day_2026-07-13.csv  1.784387e+09
# 23  usage_day_2026-07-13.csv  1.784387e+09

# %%
all_day_df = build_all_day_data("output/daily/")
# Out:
# Master dataset: 144 rows
