# %% [markdown]
# # Daily Energy Consumption

# %%
import sys
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt

# %%
SCRIPT_DIR = Path.cwd()
DATA_DIR = SCRIPT_DIR / "data" / "daily"

# %%
files = sorted(DATA_DIR.glob("*.csv"))
if not files:
    print(f"No CSVs found in {DATA_DIR}. Drop your monthly exports there and rerun.")

frames = []
for f in files:
    try:
        df = pd.read_csv(f, encoding="utf-8-sig")
        df.columns = [c.strip() for c in df.columns]
    
        # Vendor puts a leading space in the date field ("  Jul 1 2026")
        df["date"] = pd.to_datetime(df["Time period"].str.strip(), format="%b %d %Y")
        df["consumption_kwh"] = pd.to_numeric(df["Consumption"], errors="coerce")
        df["source_file"] = path.name
        df["source_mtime"] = path.stat().st_mtime
    except Exception as e:
        print(f"  ! skipping {f.name}: {e}")

combined = pd.concat(frames, ignore_index=True)
# Out:
#   ! skipping usage_day_2026-06-08.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-09.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-10.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-11.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-12.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-13.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-14.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-15.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-16.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-17.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-18.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-19.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-20.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-21.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-22.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-23.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-24.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-25.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-26.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-27.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-28.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-29.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-06-30.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-01.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-02.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-03.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-04.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-05.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-06.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-07.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-08.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-09.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-10.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-11.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-12.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-13.csv: name 'load_one' is not defined
#   ! skipping usage_day_2026-07-14.csv: name 'load_one' is not defined
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 12
#       8         frames.append(load_one(f))
#       9     except Exception as e:
#      10         print(f"  ! skipping {f.name}: {e}")
#      11
# ---> 12 combined = pd.concat(frames, ignore_index=True)
#
# File ~/Desktop/utility_billy/venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:407, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     402 else:  # pragma: no cover
#     403     raise ValueError(
#     404         "Only can inner (intersect) or outer (union) join the other axis"
#     405     )
# --> 407 objs, keys, ndims = _clean_keys_and_objs(objs, keys)
#     409 if sort is lib.no_default:
#     410     if axis == 0:
#
# File ~/Desktop/utility_billy/venv/lib/python3.13/site-packages/pandas/core/reshape/concat.py:808, in _clean_keys_and_objs(objs, keys)
#     805     objs = list(objs)
#     807 if len(objs) == 0:
# --> 808     raise ValueError("No objects to concatenate")
#     810 if keys is not None:
#     811     if not isinstance(keys, Index):
#
# ValueError: No objects to concatenate
